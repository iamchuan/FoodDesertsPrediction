# %%
import pandas as pd

# %%
tweets = pd.read_pickle(path='data/tweets_1.pkl')

# %%
latlng = tweets.loc[:, ['lat', 'lon']]

# %%
import folium
from folium.plugins import HeatMap, MarkerCluster
import random
import numpy as np

# latlng_sample, text_sample = zip(*random.sample(zip(latlng, texts), 1000))

tweet_map = folium.Map(location=[37.1, -95.7], zoom_start=4)
tweet_map.add_children(HeatMap(data=np.array(latlng), radius=6, blur=10)) #, 
#                                      popups=text_sample))
# Out:
# /Users/apple/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: FutureWarning: Method `add_children` is deprecated. Please use `add_child` instead.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('/home/shu/PycharmProjects/foodAnalysis/tweets.db')
df = pd.read_sql_query('SELECT * FROM tweetTable WHERE geo != "None"', conn)
print(df.head())

# %%
import json
get_coordinate = lambda x: json.loads(x.replace("'", "\"").replace('u', ''))[u'coordinates']
coordinates = pd.DataFrame(df.geo.map(get_coordinate).tolist(), columns=['lat', 'lng'])
coordinates

# %%
coordinates.to_pickle('./geo_df.pkl')

# %%
coord = pd.read_pickle('./geo_df.pkl')
coord

# %%
import reverse_geocoder as rg
import pandas as pd
coord = pd.read_pickle('./geo_df.pkl')

# %%
tuple(tuple(x) for x in coord[:5].to_records(index=False))

# %%
results = rg.search([tuple(x) for x in coord[:5].to_records(index=False)])

# %%
import reverse_geocoder as rg

coordinates = tuple(tuple(x) for x in coord.to_records(index=False))

results = rg.search(coordinates) # default mode = 2

print results
